# %% [markdown]
# Import Libraries

# %%
import time
import numpy as np
import pandas as pd

# Machine learning and evaluation
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# SVM model and feature scaling
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler

# Sampling techniques
from sklearn.utils import resample
from imblearn.over_sampling import SMOTE

# %% [markdown]
# Load and Display Data

# %%
df = pd.read_csv('./../Dataset/StrongPassword.csv')

df.head()
# Out:
#   subject  sessionIndex  rep  H.period  DD.period.t  UD.period.t     H.t  \
# 0    s002             1    1    0.1491       0.3979       0.2488  0.1069
# 1    s002             1    2    0.1111       0.3451       0.2340  0.0694
# 2    s002             1    3    0.1328       0.2072       0.0744  0.0731
# 3    s002             1    4    0.1291       0.2515       0.1224  0.1059
# 4    s002             1    5    0.1249       0.2317       0.1068  0.0895
#
#    DD.t.i  UD.t.i     H.i  ...     H.a  DD.a.n  UD.a.n     H.n  DD.n.l  \
# 0  0.1674  0.0605  0.1169  ...  0.1349  0.1484  0.0135  0.0932  0.3515
# 1  0.1283  0.0589  0.0908  ...  0.1412  0.2558  0.1146  0.1146  0.2642
# 2  0.1291  0.0560  0.0821  ...  0.1621  0.2332  0.0711  0.1172  0.2705
# 3  0.2495  0.1436  0.1040  ...  0.1457  0.1629  0.0172  0.0866  0.2341
# 4  0.1676  0.0781  0.0903  ...  0.1312  0.1582  0.0270  0.0884  0.2517
#
#    UD.n.l     H.l  DD.l.Return  UD.l.Return  H.Return
# 0  0.2583  0.1338       0.3509       0.2171    0.0742
# 1  0.1496  0.0839       0.2756       0.1917    0.0747
# 2  0.1533  0.1085       0.2847       0.1762    0.0945
# 3  0.1475  0.0845       0.3232       0.2387    0.0813
# 4  0.1633  0.0903       0.2517       0.1614    0.0818
#
# [5 rows x 34 columns]

# %% [markdown]
# Feature Extraction Functions

# %%
# Define Feature Extraction Functions
def get_feature_columns(df):
    """
    Extract column names for dwell times, latency, and flight times.
    """
    dwell_columns = [col for col in df.columns if col.startswith('H.')]
    latency_columns = [col for col in df.columns if col.startswith('DD.')]
    flight_columns = [col for col in df.columns if col.startswith('UD.')]
    return dwell_columns, latency_columns, flight_columns

def extract_features(df, feature_set):
    """
    Extract features based on the specified feature set.
    feature_set can be 'first_order', 'second_order', or 'combined'.
    """
    dwell_columns, latency_columns, flight_columns = get_feature_columns(df)
    
    # First-order features
    first_order_features = pd.concat([
        df[dwell_columns],
        df[latency_columns],
        df[flight_columns]
    ], axis=1)
    
    if feature_set == 'first_order':
        return first_order_features
    elif feature_set == 'second_order':
        # Calculate second-order features
        second_order_features = extract_second_order_features(first_order_features, dwell_columns, latency_columns, flight_columns)
        return second_order_features
    elif feature_set == 'combined':
        # Combine first and second-order features
        second_order_features = extract_second_order_features(first_order_features, dwell_columns, latency_columns, flight_columns)
        combined_features = pd.concat([first_order_features, second_order_features], axis=1)
        return combined_features
    else:
        raise ValueError("Invalid feature set specified. Choose from 'first_order', 'second_order', or 'combined'.")

def extract_second_order_features(first_order_df, dwell_columns, latency_columns, flight_columns):
    """
    Calculate second-order features including min, max, mean, std, and slope.
    """
    # Mean and Standard Deviation
    second_order_features = {
        'mean_dwell_time': first_order_df[dwell_columns].mean(axis=1),
        'std_dwell_time': first_order_df[dwell_columns].std(axis=1),
        'mean_latency': first_order_df[latency_columns].mean(axis=1),
        'std_latency': first_order_df[latency_columns].std(axis=1),
        'mean_flight_time': first_order_df[flight_columns].mean(axis=1),
        'std_flight_time': first_order_df[flight_columns].std(axis=1),
    }
    
    # Minimum and Maximum Values
    second_order_features.update({
        'min_dwell_time': first_order_df[dwell_columns].min(axis=1),
        'max_dwell_time': first_order_df[dwell_columns].max(axis=1),
        'min_latency': first_order_df[latency_columns].min(axis=1),
        'max_latency': first_order_df[latency_columns].max(axis=1),
        'min_flight_time': first_order_df[flight_columns].min(axis=1),
        'max_flight_time': first_order_df[flight_columns].max(axis=1),
    })
    
    # Slope Features
    # Compute the difference between consecutive elements in each row
    dwell_slopes = first_order_df[dwell_columns].diff(axis=1).iloc[:, 1:]
    latency_slopes = first_order_df[latency_columns].diff(axis=1).iloc[:, 1:]
    flight_slopes = first_order_df[flight_columns].diff(axis=1).iloc[:, 1:]
    
    # Include mean and standard deviation of slopes as second-order features
    second_order_features.update({
        'mean_dwell_slope': dwell_slopes.mean(axis=1),
        'std_dwell_slope': dwell_slopes.std(axis=1),
        'mean_latency_slope': latency_slopes.mean(axis=1),
        'std_latency_slope': latency_slopes.std(axis=1),
        'mean_flight_slope': flight_slopes.mean(axis=1),
        'std_flight_slope': flight_slopes.std(axis=1),
    })
    
    # Convert to DataFrame
    second_order_df = pd.DataFrame(second_order_features)
    return second_order_df

# %% [markdown]
# Define Model Training and Evaluation Function (Using Hybrid Sampling to balance the dataset)

# %%
def train_and_evaluate_user(user, df, feature_set, feature_set_name):
    start_time = time.time()

    # Buat label biner: 1 untuk pengguna asli, 0 untuk impostor
    user_df = df.copy()
    user_df['label'] = (user_df['subject'] == user).astype(int)

    # Ekstraksi fitur
    X = extract_features(user_df, feature_set)
    y = user_df['label']

    # Pisahkan sampel asli dan impostor
    genuine = user_df[user_df['label'] == 1]
    imposters = user_df[user_df['label'] == 0]

    X_genuine = X.loc[genuine.index]
    y_genuine = y.loc[genuine.index]

    X_imposters = X.loc[imposters.index]
    y_imposters = y.loc[imposters.index]

    # Undersample imposters
    n_imposter_samples = len(genuine) * 5  # Sesuaikan multiplier sesuai kebutuhan
    imposters_downsampled_X, imposters_downsampled_y = resample(
        X_imposters,
        y_imposters,
        replace=False,
        n_samples=n_imposter_samples,
        random_state=42,
        stratify=y_imposters
    )

    # Gabungkan data asli dengan imposters yang telah di-undersample
    X_combined = pd.concat([X_genuine, imposters_downsampled_X])
    y_combined = pd.concat([y_genuine, imposters_downsampled_y])

    # Lakukan train-test split sebelum oversampling
    X_train, X_test, y_train, y_test = train_test_split(
        X_combined, y_combined, test_size=0.2, random_state=42, stratify=y_combined
    )

    # Terapkan SMOTE hanya pada data pelatihan
    smote = SMOTE(random_state=42)
    X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

    # Scaling fitur (penting untuk SVM)
    scaler = StandardScaler()
    X_train_resampled = scaler.fit_transform(X_train_resampled)
    X_test = scaler.transform(X_test)

    # Inisialisasi model SVM
    model = SVC(kernel='rbf', probability=True, random_state=42)

    # Latih model
    model.fit(X_train_resampled, y_train_resampled)

    # Prediksi
    y_pred = model.predict(X_test)

    # Hitung metrik
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, zero_division=0)
    recall = recall_score(y_test, y_pred, zero_division=0)
    f1 = f1_score(y_test, y_pred, zero_division=0)

    # Hitung waktu pelatihan
    end_time = time.time()
    training_time = end_time - start_time

    # Cetak metrik
    print(f"Metrics for user {user} using {feature_set_name}:")
    print(f" - Accuracy: {accuracy * 100:.2f}%")
    print(f" - Precision: {precision:.2f}")
    print(f" - Recall: {recall:.2f}")
    print(f" - F1-Score: {f1:.2f}")
    print(f" - Training time: {training_time:.2f} seconds\n")

    return accuracy, precision, recall, f1, training_time

# %% [markdown]
# Train Models and Evaluate Performance

# %%
# Get list of unique users
users = df['subject'].unique()

# Define feature sets to use
feature_sets = {
    'First-Order Features': 'first_order',
    'Second-Order Features': 'second_order',
    'Combined Features': 'combined'
}

# Loop over feature sets
for feature_set_name, feature_set_key in feature_sets.items():
    print(f"\n=== Training models using {feature_set_name} ===\n")

    # Initialize lists to store metrics
    accuracies = []
    precisions = []
    recalls = []
    f1_scores = []
    training_times = []

    # Loop over each user
    for user in users:
        accuracy, precision, recall, f1, training_time = train_and_evaluate_user(
            user, df, feature_set_key, feature_set_name
        )
        accuracies.append(accuracy)
        precisions.append(precision)
        recalls.append(recall)
        f1_scores.append(f1)
        training_times.append(training_time)

    # Compute average metrics across all users for this feature set
    average_accuracy = np.mean(accuracies)
    average_precision = np.mean(precisions)
    average_recall = np.mean(recalls)
    average_f1_score = np.mean(f1_scores)
    average_training_time = np.mean(training_times)

    print(f"Average Metrics Across All Users for {feature_set_name}:")
    print(f" - Average Accuracy: {average_accuracy * 100:.2f}%")
    print(f" - Average Precision: {average_precision:.2f}")
    print(f" - Average Recall: {average_recall:.2f}")
    print(f" - Average F1-Score: {average_f1_score:.2f}")
    print(f" - Average Training Time per User: {average_training_time:.2f} seconds\n")
# Out:
# === Training models using First-Order Features ===
#
# Metrics for user s002 using First-Order Features:
#  - Accuracy: 95.00%
#  - Precision: 0.82
#  - Recall: 0.90
#  - F1-Score: 0.86
#  - Training time: 0.55 seconds
#
# Metrics for user s003 using First-Order Features:
#  - Accuracy: 97.50%
#  - Precision: 0.90
#  - Recall: 0.96
#  - F1-Score: 0.93
#  - Training time: 0.40 seconds
#
# Metrics for user s004 using First-Order Features:
#  - Accuracy: 97.29%
#  - Precision: 0.90
#  - Recall: 0.94
#  - F1-Score: 0.92
#  - Training time: 0.37 seconds
#
# Metrics for user s005 using First-Order Features:
#  - Accuracy: 97.92%
#  - Precision: 0.95
#  - Recall: 0.93
#  - F1-Score: 0.94
#  - Training time: 0.29 seconds
#
# Metrics for user s007 using First-Order Features:
#  - Accuracy: 96.25%
#  - Precision: 0.85
#  - Recall: 0.94
#  - F1-Score: 0.89
#  - Training time: 0.52 seconds
#
# Metrics for user s008 using First-Order Features:
#  - Accuracy: 95.00%
#  - Precision: 0.80
#  - Recall: 0.93
#  - F1-Score: 0.86
#  - Training time: 0.52 seconds
#
# Metrics for user s010 using First-Order Features:
#  - Accuracy: 98.54%
#  - Precision: 0.97
#  - Recall: 0.94
#  - F1-Score: 0.96
#  - Training time: 0.28 seconds
#
# Metrics for user s011 using First-Order Features:
#  - Accuracy: 98.12%
#  - Precision: 0.95
#  - Recall: 0.94
#  - F1-Score: 0.94
#  - Training time: 0.46 seconds
#
# Metrics for user s012 using First-Order Features:
#  - Accuracy: 98.54%
#  - Precision: 0.96
#  - Recall: 0.95
#  - F1-Score: 0.96
#  - Training time: 0.42 seconds
#
# Metrics for user s013 using First-Order Features:
#  - Accuracy: 96.46%
#  - Precision: 0.85
#  - Recall: 0.95
#  - F1-Score: 0.90
#  - Training time: 0.39 seconds
#
# Metrics for user s015 using First-Order Features:
#  - Accuracy: 96.25%
#  - Precision: 0.86
#  - Recall: 0.93
#  - F1-Score: 0.89
#  - Training time: 0.57 seconds
#
# Metrics for user s016 using First-Order Features:
#  - Accuracy: 97.71%
#  - Precision: 0.92
#  - Recall: 0.95
#  - F1-Score: 0.93
#  - Training time: 0.37 seconds
#
# Metrics for user s017 using First-Order Features:
#  - Accuracy: 98.33%
#  - Precision: 0.95
#  - Recall: 0.95
#  - F1-Score: 0.95
#  - Training time: 0.24 seconds
#
# Metrics for user s018 using First-Order Features:
#  - Accuracy: 97.08%
#  - Precision: 0.93
#  - Recall: 0.89
#  - F1-Score: 0.91
#  - Training time: 0.55 seconds
#
# Metrics for user s019 using First-Order Features:
#  - Accuracy: 98.96%
#  - Precision: 0.99
#  - Recall: 0.95
#  - F1-Score: 0.97
#  - Training time: 0.25 seconds
#
# Metrics for user s020 using First-Order Features:
#  - Accuracy: 95.00%
#  - Precision: 0.87
#  - Recall: 0.82
#  - F1-Score: 0.85
#  - Training time: 0.54 seconds
#
# Metrics for user s021 using First-Order Features:
#  - Accuracy: 96.67%
#  - Precision: 0.88
#  - Recall: 0.93
#  - F1-Score: 0.90
#  - Training time: 0.46 seconds
#
# Metrics for user s022 using First-Order Features:
#  - Accuracy: 99.38%
#  - Precision: 0.98
#  - Recall: 0.99
#  - F1-Score: 0.98
#  - Training time: 0.25 seconds
#
# Metrics for user s024 using First-Order Features:
#  - Accuracy: 99.17%
#  - Precision: 0.96
#  - Recall: 0.99
#  - F1-Score: 0.98
#  - Training time: 0.33 seconds
#
# Metrics for user s025 using First-Order Features:
#  - Accuracy: 98.96%
#  - Precision: 0.97
#  - Recall: 0.96
#  - F1-Score: 0.97
#  - Training time: 0.29 seconds
#
# Metrics for user s026 using First-Order Features:
#  - Accuracy: 96.88%
#  - Precision: 0.93
#  - Recall: 0.88
#  - F1-Score: 0.90
#  - Training time: 0.49 seconds
#
# Metrics for user s027 using First-Order Features:
#  - Accuracy: 97.71%
#  - Precision: 0.91
#  - Recall: 0.96
#  - F1-Score: 0.93
#  - Training time: 0.31 seconds
#
# Metrics for user s028 using First-Order Features:
#  - Accuracy: 98.96%
#  - Precision: 0.96
#  - Recall: 0.97
#  - F1-Score: 0.97
#  - Training time: 0.30 seconds
#
# Metrics for user s029 using First-Order Features:
#  - Accuracy: 97.50%
#  - Precision: 0.90
#  - Recall: 0.95
#  - F1-Score: 0.93
#  - Training time: 0.42 seconds
#
# Metrics for user s030 using First-Order Features:
#  - Accuracy: 97.71%
#  - Precision: 0.97
#  - Recall: 0.89
#  - F1-Score: 0.93
#  - Training time: 0.34 seconds
#
# Metrics for user s031 using First-Order Features:
#  - Accuracy: 95.42%
#  - Precision: 0.85
#  - Recall: 0.89
#  - F1-Score: 0.87
#  - Training time: 0.67 seconds
#
# Metrics for user s032 using First-Order Features:
#  - Accuracy: 92.71%
#  - Precision: 0.74
#  - Recall: 0.88
#  - F1-Score: 0.80
#  - Training time: 0.77 seconds
#
# Metrics for user s033 using First-Order Features:
#  - Accuracy: 99.17%
#  - Precision: 1.00
#  - Recall: 0.95
#  - F1-Score: 0.97
#  - Training time: 0.29 seconds
#
# Metrics for user s034 using First-Order Features:
#  - Accuracy: 96.04%
#  - Precision: 0.85
#  - Recall: 0.93
#  - F1-Score: 0.89
#  - Training time: 0.52 seconds
#
# Metrics for user s035 using First-Order Features:
#  - Accuracy: 98.54%
#  - Precision: 0.99
#  - Recall: 0.93
#  - F1-Score: 0.95
#  - Training time: 0.44 seconds
#
# Metrics for user s036 using First-Order Features:
#  - Accuracy: 99.79%
#  - Precision: 1.00
#  - Recall: 0.99
#  - F1-Score: 0.99
#  - Training time: 0.17 seconds
#
# Metrics for user s037 using First-Order Features:
#  - Accuracy: 96.46%
#  - Precision: 0.89
#  - Recall: 0.90
#  - F1-Score: 0.89
#  - Training time: 0.52 seconds
#
# Metrics for user s038 using First-Order Features:
#  - Accuracy: 98.12%
#  - Precision: 0.95
#  - Recall: 0.94
#  - F1-Score: 0.94
#  - Training time: 0.40 seconds
#
# Metrics for user s039 using First-Order Features:
#  - Accuracy: 98.54%
#  - Precision: 0.95
#  - Recall: 0.96
#  - F1-Score: 0.96
#  - Training time: 0.38 seconds
#
# Metrics for user s040 using First-Order Features:
#  - Accuracy: 97.08%
#  - Precision: 0.96
#  - Recall: 0.86
#  - F1-Score: 0.91
#  - Training time: 0.34 seconds
#
# Metrics for user s041 using First-Order Features:
#  - Accuracy: 97.92%
#  - Precision: 0.93
#  - Recall: 0.95
#  - F1-Score: 0.94
#  - Training time: 0.40 seconds
#
# Metrics for user s042 using First-Order Features:
#  - Accuracy: 99.58%
#  - Precision: 0.99
#  - Recall: 0.99
#  - F1-Score: 0.99
#  - Training time: 0.30 seconds
#
# Metrics for user s043 using First-Order Features:
#  - Accuracy: 99.17%
#  - Precision: 0.99
#  - Recall: 0.96
#  - F1-Score: 0.97
#  - Training time: 0.25 seconds
#
# Metrics for user s044 using First-Order Features:
#  - Accuracy: 97.71%
#  - Precision: 0.93
#  - Recall: 0.94
#  - F1-Score: 0.93
#  - Training time: 0.42 seconds
#
# Metrics for user s046 using First-Order Features:
#  - Accuracy: 96.46%
#  - Precision: 0.87
#  - Recall: 0.93
#  - F1-Score: 0.90
#  - Training time: 0.54 seconds
#
# Metrics for user s047 using First-Order Features:
#  - Accuracy: 97.92%
#  - Precision: 0.93
#  - Recall: 0.95
#  - F1-Score: 0.94
#  - Training time: 0.49 seconds
#
# Metrics for user s048 using First-Order Features:
#  - Accuracy: 96.25%
#  - Precision: 0.89
#  - Recall: 0.89
#  - F1-Score: 0.89
#  - Training time: 0.39 seconds
#
# Metrics for user s049 using First-Order Features:
#  - Accuracy: 98.54%
#  - Precision: 0.97
#  - Recall: 0.94
#  - F1-Score: 0.96
#  - Training time: 0.28 seconds
#
# Metrics for user s050 using First-Order Features:
#  - Accuracy: 96.04%
#  - Precision: 0.89
#  - Recall: 0.88
#  - F1-Score: 0.88
#  - Training time: 0.47 seconds
#
# Metrics for user s051 using First-Order Features:
#  - Accuracy: 97.92%
#  - Precision: 0.92
#  - Recall: 0.96
#  - F1-Score: 0.94
#  - Training time: 0.44 seconds
#
# Metrics for user s052 using First-Order Features:
#  - Accuracy: 99.38%
#  - Precision: 1.00
#  - Recall: 0.96
#  - F1-Score: 0.98
#  - Training time: 0.22 seconds
#
# Metrics for user s053 using First-Order Features:
#  - Accuracy: 99.17%
#  - Precision: 1.00
#  - Recall: 0.95
#  - F1-Score: 0.97
#  - Training time: 0.26 seconds
#
# Metrics for user s054 using First-Order Features:
#  - Accuracy: 96.46%
#  - Precision: 0.88
#  - Recall: 0.91
#  - F1-Score: 0.90
#  - Training time: 0.50 seconds
#
# Metrics for user s055 using First-Order Features:
#  - Accuracy: 98.75%
#  - Precision: 0.94
#  - Recall: 0.99
#  - F1-Score: 0.96
#  - Training time: 0.29 seconds
#
# Metrics for user s056 using First-Order Features:
#  - Accuracy: 96.88%
#  - Precision: 0.89
#  - Recall: 0.93
#  - F1-Score: 0.91
#  - Training time: 0.46 seconds
#
# Metrics for user s057 using First-Order Features:
#  - Accuracy: 98.75%
#  - Precision: 0.95
#  - Recall: 0.97
#  - F1-Score: 0.96
#  - Training time: 0.47 seconds
#
# Average Metrics Across All Users for First-Order Features:
#  - Average Accuracy: 97.56%
#  - Average Precision: 0.92
#  - Average Recall: 0.93
#  - Average F1-Score: 0.93
#  - Average Training Time per User: 0.40 seconds
#
#
# === Training models using Second-Order Features ===
#
# Metrics for user s002 using Second-Order Features:
#  - Accuracy: 84.17%
#  - Precision: 0.52
#  - Recall: 0.82
#  - F1-Score: 0.63
#  - Training time: 0.73 seconds
#
# Metrics for user s003 using Second-Order Features:
#  - Accuracy: 95.21%
#  - Precision: 0.79
#  - Recall: 0.97
#  - F1-Score: 0.87
#  - Training time: 0.48 seconds
#
# Metrics for user s004 using Second-Order Features:
#  - Accuracy: 88.54%
#  - Precision: 0.61
#  - Recall: 0.90
#  - F1-Score: 0.72
#  - Training time: 0.54 seconds
#
# Metrics for user s005 using Second-Order Features:
#  - Accuracy: 94.58%
#  - Precision: 0.79
#  - Recall: 0.91
#  - F1-Score: 0.85
#  - Training time: 0.32 seconds
#
# Metrics for user s007 using Second-Order Features:
#  - Accuracy: 83.96%
#  - Precision: 0.51
#  - Recall: 0.91
#  - F1-Score: 0.65
#  - Training time: 0.79 seconds
#
# Metrics for user s008 using Second-Order Features:
#  - Accuracy: 86.67%
#  - Precision: 0.57
#  - Recall: 0.81
#  - F1-Score: 0.67
#  - Training time: 0.64 seconds
#
# Metrics for user s010 using Second-Order Features:
#  - Accuracy: 93.75%
#  - Precision: 0.75
#  - Recall: 0.94
#  - F1-Score: 0.83
#  - Training time: 0.39 seconds
#
# Metrics for user s011 using Second-Order Features:
#  - Accuracy: 95.42%
#  - Precision: 0.83
#  - Recall: 0.91
#  - F1-Score: 0.87
#  - Training time: 0.38 seconds
#
# Metrics for user s012 using Second-Order Features:
#  - Accuracy: 97.92%
#  - Precision: 0.89
#  - Recall: 1.00
#  - F1-Score: 0.94
#  - Training time: 0.34 seconds
#
# Metrics for user s013 using Second-Order Features:
#  - Accuracy: 91.46%
#  - Precision: 0.67
#  - Recall: 0.96
#  - F1-Score: 0.79
#  - Training time: 0.49 seconds
#
# Metrics for user s015 using Second-Order Features:
#  - Accuracy: 88.33%
#  - Precision: 0.60
#  - Recall: 0.90
#  - F1-Score: 0.72
#  - Training time: 0.54 seconds
#
# Metrics for user s016 using Second-Order Features:
#  - Accuracy: 93.75%
#  - Precision: 0.77
#  - Recall: 0.90
#  - F1-Score: 0.83
#  - Training time: 0.34 seconds
#
# Metrics for user s017 using Second-Order Features:
#  - Accuracy: 95.62%
#  - Precision: 0.79
#  - Recall: 1.00
#  - F1-Score: 0.88
#  - Training time: 0.26 seconds
#
# Metrics for user s018 using Second-Order Features:
#  - Accuracy: 92.50%
#  - Precision: 0.74
#  - Recall: 0.84
#  - F1-Score: 0.79
#  - Training time: 0.57 seconds
#
# Metrics for user s019 using Second-Order Features:
#  - Accuracy: 97.71%
#  - Precision: 0.93
#  - Recall: 0.94
#  - F1-Score: 0.93
#  - Training time: 0.33 seconds
#
# Metrics for user s020 using Second-Order Features:
#  - Accuracy: 89.38%
#  - Precision: 0.65
#  - Recall: 0.78
#  - F1-Score: 0.71
#  - Training time: 0.69 seconds
#
# Metrics for user s021 using Second-Order Features:
#  - Accuracy: 92.29%
#  - Precision: 0.73
#  - Recall: 0.86
#  - F1-Score: 0.79
#  - Training time: 0.56 seconds
#
# Metrics for user s022 using Second-Order Features:
#  - Accuracy: 97.71%
#  - Precision: 0.89
#  - Recall: 0.99
#  - F1-Score: 0.93
#  - Training time: 0.24 seconds
#
# Metrics for user s024 using Second-Order Features:
#  - Accuracy: 97.08%
#  - Precision: 0.87
#  - Recall: 0.97
#  - F1-Score: 0.92
#  - Training time: 0.32 seconds
#
# Metrics for user s025 using Second-Order Features:
#  - Accuracy: 98.54%
#  - Precision: 0.94
#  - Recall: 0.97
#  - F1-Score: 0.96
#  - Training time: 0.26 seconds
#
# Metrics for user s026 using Second-Order Features:
#  - Accuracy: 95.21%
#  - Precision: 0.81
#  - Recall: 0.94
#  - F1-Score: 0.87
#  - Training time: 0.43 seconds
#
# Metrics for user s027 using Second-Order Features:
#  - Accuracy: 93.54%
#  - Precision: 0.74
#  - Recall: 0.94
#  - F1-Score: 0.83
#  - Training time: 0.42 seconds
#
# Metrics for user s028 using Second-Order Features:
#  - Accuracy: 98.12%
#  - Precision: 0.92
#  - Recall: 0.97
#  - F1-Score: 0.95
#  - Training time: 0.25 seconds
#
# Metrics for user s029 using Second-Order Features:
#  - Accuracy: 83.96%
#  - Precision: 0.51
#  - Recall: 0.82
#  - F1-Score: 0.63
#  - Training time: 0.59 seconds
#
# Metrics for user s030 using Second-Order Features:
#  - Accuracy: 96.25%
#  - Precision: 0.86
#  - Recall: 0.93
#  - F1-Score: 0.89
#  - Training time: 0.38 seconds
#
# Metrics for user s031 using Second-Order Features:
#  - Accuracy: 88.75%
#  - Precision: 0.61
#  - Recall: 0.88
#  - F1-Score: 0.72
#  - Training time: 0.70 seconds
#
# Metrics for user s032 using Second-Order Features:
#  - Accuracy: 81.46%
#  - Precision: 0.47
#  - Recall: 0.84
#  - F1-Score: 0.60
#  - Training time: 0.91 seconds
#
# Metrics for user s033 using Second-Order Features:
#  - Accuracy: 97.71%
#  - Precision: 0.93
#  - Recall: 0.94
#  - F1-Score: 0.93
#  - Training time: 0.28 seconds
#
# Metrics for user s034 using Second-Order Features:
#  - Accuracy: 88.96%
#  - Precision: 0.62
#  - Recall: 0.86
#  - F1-Score: 0.72
#  - Training time: 0.67 seconds
#
# Metrics for user s035 using Second-Order Features:
#  - Accuracy: 89.79%
#  - Precision: 0.63
#  - Recall: 0.93
#  - F1-Score: 0.75
#  - Training time: 0.63 seconds
#
# Metrics for user s036 using Second-Order Features:
#  - Accuracy: 99.58%
#  - Precision: 0.98
#  - Recall: 1.00
#  - F1-Score: 0.99
#  - Training time: 0.18 seconds
#
# Metrics for user s037 using Second-Order Features:
#  - Accuracy: 81.88%
#  - Precision: 0.47
#  - Recall: 0.75
#  - F1-Score: 0.58
#  - Training time: 0.79 seconds
#
# Metrics for user s038 using Second-Order Features:
#  - Accuracy: 86.04%
#  - Precision: 0.55
#  - Recall: 0.88
#  - F1-Score: 0.68
#  - Training time: 0.66 seconds
#
# Metrics for user s039 using Second-Order Features:
#  - Accuracy: 97.29%
#  - Precision: 0.90
#  - Recall: 0.94
#  - F1-Score: 0.92
#  - Training time: 0.36 seconds
#
# Metrics for user s040 using Second-Order Features:
#  - Accuracy: 95.00%
#  - Precision: 0.79
#  - Recall: 0.95
#  - F1-Score: 0.86
#  - Training time: 0.40 seconds
#
# Metrics for user s041 using Second-Order Features:
#  - Accuracy: 94.79%
#  - Precision: 0.79
#  - Recall: 0.94
#  - F1-Score: 0.86
#  - Training time: 0.32 seconds
#
# Metrics for user s042 using Second-Order Features:
#  - Accuracy: 96.46%
#  - Precision: 0.87
#  - Recall: 0.93
#  - F1-Score: 0.90
#  - Training time: 0.40 seconds
#
# Metrics for user s043 using Second-Order Features:
#  - Accuracy: 97.50%
#  - Precision: 0.88
#  - Recall: 0.99
#  - F1-Score: 0.93
#  - Training time: 0.29 seconds
#
# Metrics for user s044 using Second-Order Features:
#  - Accuracy: 94.79%
#  - Precision: 0.79
#  - Recall: 0.94
#  - F1-Score: 0.86
#  - Training time: 0.48 seconds
#
# Metrics for user s046 using Second-Order Features:
#  - Accuracy: 91.25%
#  - Precision: 0.69
#  - Recall: 0.85
#  - F1-Score: 0.76
#  - Training time: 0.59 seconds
#
# Metrics for user s047 using Second-Order Features:
#  - Accuracy: 90.42%
#  - Precision: 0.65
#  - Recall: 0.90
#  - F1-Score: 0.76
#  - Training time: 0.60 seconds
#
# Metrics for user s048 using Second-Order Features:
#  - Accuracy: 88.75%
#  - Precision: 0.61
#  - Recall: 0.90
#  - F1-Score: 0.73
#  - Training time: 0.64 seconds
#
# Metrics for user s049 using Second-Order Features:
#  - Accuracy: 98.12%
#  - Precision: 0.92
#  - Recall: 0.97
#  - F1-Score: 0.95
#  - Training time: 0.34 seconds
#
# Metrics for user s050 using Second-Order Features:
#  - Accuracy: 87.08%
#  - Precision: 0.58
#  - Recall: 0.79
#  - F1-Score: 0.67
#  - Training time: 0.80 seconds
#
# Metrics for user s051 using Second-Order Features:
#  - Accuracy: 89.17%
#  - Precision: 0.62
#  - Recall: 0.90
#  - F1-Score: 0.73
#  - Training time: 0.54 seconds
#
# Metrics for user s052 using Second-Order Features:
#  - Accuracy: 97.50%
#  - Precision: 0.90
#  - Recall: 0.96
#  - F1-Score: 0.93
#  - Training time: 0.23 seconds
#
# Metrics for user s053 using Second-Order Features:
#  - Accuracy: 93.96%
#  - Precision: 0.76
#  - Recall: 0.93
#  - F1-Score: 0.84
#  - Training time: 0.37 seconds
#
# Metrics for user s054 using Second-Order Features:
#  - Accuracy: 87.29%
#  - Precision: 0.58
#  - Recall: 0.88
#  - F1-Score: 0.70
#  - Training time: 0.81 seconds
#
# Metrics for user s055 using Second-Order Features:
#  - Accuracy: 93.33%
#  - Precision: 0.73
#  - Recall: 0.95
#  - F1-Score: 0.83
#  - Training time: 0.46 seconds
#
# Metrics for user s056 using Second-Order Features:
#  - Accuracy: 88.12%
#  - Precision: 0.60
#  - Recall: 0.88
#  - F1-Score: 0.71
#  - Training time: 0.65 seconds
#
# Metrics for user s057 using Second-Order Features:
#  - Accuracy: 90.83%
#  - Precision: 0.67
#  - Recall: 0.89
#  - F1-Score: 0.76
#  - Training time: 0.62 seconds
#
# Average Metrics Across All Users for Second-Order Features:
#  - Average Accuracy: 92.30%
#  - Average Precision: 0.73
#  - Average Recall: 0.91
#  - Average F1-Score: 0.81
#  - Average Training Time per User: 0.49 seconds
#
#
# === Training models using Combined Features ===
#
# Metrics for user s002 using Combined Features:
#  - Accuracy: 94.38%
#  - Precision: 0.78
#  - Recall: 0.91
#  - F1-Score: 0.84
#  - Training time: 0.50 seconds
#
# Metrics for user s003 using Combined Features:
#  - Accuracy: 97.50%
#  - Precision: 0.90
#  - Recall: 0.96
#  - F1-Score: 0.93
#  - Training time: 0.40 seconds
#
# Metrics for user s004 using Combined Features:
#  - Accuracy: 96.46%
#  - Precision: 0.86
#  - Recall: 0.94
#  - F1-Score: 0.90
#  - Training time: 0.37 seconds
#
# Metrics for user s005 using Combined Features:
#  - Accuracy: 97.92%
#  - Precision: 0.95
#  - Recall: 0.93
#  - F1-Score: 0.94
#  - Training time: 0.30 seconds
#
# Metrics for user s007 using Combined Features:
#  - Accuracy: 96.67%
#  - Precision: 0.86
#  - Recall: 0.95
#  - F1-Score: 0.90
#  - Training time: 0.49 seconds
#
# Metrics for user s008 using Combined Features:
#  - Accuracy: 94.17%
#  - Precision: 0.78
#  - Recall: 0.91
#  - F1-Score: 0.84
#  - Training time: 0.47 seconds
#
# Metrics for user s010 using Combined Features:
#  - Accuracy: 98.96%
#  - Precision: 0.96
#  - Recall: 0.97
#  - F1-Score: 0.97
#  - Training time: 0.30 seconds
#
# Metrics for user s011 using Combined Features:
#  - Accuracy: 98.12%
#  - Precision: 0.96
#  - Recall: 0.93
#  - F1-Score: 0.94
#  - Training time: 0.42 seconds
#
# Metrics for user s012 using Combined Features:
#  - Accuracy: 98.75%
#  - Precision: 0.96
#  - Recall: 0.96
#  - F1-Score: 0.96
#  - Training time: 0.41 seconds
#
# Metrics for user s013 using Combined Features:
#  - Accuracy: 97.29%
#  - Precision: 0.88
#  - Recall: 0.97
#  - F1-Score: 0.92
#  - Training time: 0.41 seconds
#
# Metrics for user s015 using Combined Features:
#  - Accuracy: 94.79%
#  - Precision: 0.80
#  - Recall: 0.91
#  - F1-Score: 0.85
#  - Training time: 0.63 seconds
#
# Metrics for user s016 using Combined Features:
#  - Accuracy: 97.71%
#  - Precision: 0.93
#  - Recall: 0.94
#  - F1-Score: 0.93
#  - Training time: 0.36 seconds
#
# Metrics for user s017 using Combined Features:
#  - Accuracy: 98.12%
#  - Precision: 0.94
#  - Recall: 0.95
#  - F1-Score: 0.94
#  - Training time: 0.28 seconds
#
# Metrics for user s018 using Combined Features:
#  - Accuracy: 96.67%
#  - Precision: 0.93
#  - Recall: 0.86
#  - F1-Score: 0.90
#  - Training time: 0.48 seconds
#
# Metrics for user s019 using Combined Features:
#  - Accuracy: 98.96%
#  - Precision: 0.99
#  - Recall: 0.95
#  - F1-Score: 0.97
#  - Training time: 0.28 seconds
#
# Metrics for user s020 using Combined Features:
#  - Accuracy: 95.00%
#  - Precision: 0.88
#  - Recall: 0.81
#  - F1-Score: 0.84
#  - Training time: 0.52 seconds
#
# Metrics for user s021 using Combined Features:
#  - Accuracy: 96.88%
#  - Precision: 0.89
#  - Recall: 0.93
#  - F1-Score: 0.91
#  - Training time: 0.45 seconds
#
# Metrics for user s022 using Combined Features:
#  - Accuracy: 98.75%
#  - Precision: 0.94
#  - Recall: 0.99
#  - F1-Score: 0.96
#  - Training time: 0.25 seconds
#
# Metrics for user s024 using Combined Features:
#  - Accuracy: 98.75%
#  - Precision: 0.95
#  - Recall: 0.97
#  - F1-Score: 0.96
#  - Training time: 0.33 seconds
#
# Metrics for user s025 using Combined Features:
#  - Accuracy: 99.17%
#  - Precision: 0.99
#  - Recall: 0.96
#  - F1-Score: 0.97
#  - Training time: 0.34 seconds
#
# Metrics for user s026 using Combined Features:
#  - Accuracy: 97.71%
#  - Precision: 0.95
#  - Recall: 0.91
#  - F1-Score: 0.93
#  - Training time: 0.39 seconds
#
# Metrics for user s027 using Combined Features:
#  - Accuracy: 97.92%
#  - Precision: 0.93
#  - Recall: 0.95
#  - F1-Score: 0.94
#  - Training time: 0.33 seconds
#
# Metrics for user s028 using Combined Features:
#  - Accuracy: 98.96%
#  - Precision: 0.97
#  - Recall: 0.96
#  - F1-Score: 0.97
#  - Training time: 0.33 seconds
#
# Metrics for user s029 using Combined Features:
#  - Accuracy: 96.04%
#  - Precision: 0.86
#  - Recall: 0.91
#  - F1-Score: 0.88
#  - Training time: 0.43 seconds
#
# Metrics for user s030 using Combined Features:
#  - Accuracy: 97.92%
#  - Precision: 0.97
#  - Recall: 0.90
#  - F1-Score: 0.94
#  - Training time: 0.43 seconds
#
# Metrics for user s031 using Combined Features:
#  - Accuracy: 94.17%
#  - Precision: 0.80
#  - Recall: 0.86
#  - F1-Score: 0.83
#  - Training time: 0.62 seconds
#
# Metrics for user s032 using Combined Features:
#  - Accuracy: 92.71%
#  - Precision: 0.73
#  - Recall: 0.89
#  - F1-Score: 0.80
#  - Training time: 0.72 seconds
#
# Metrics for user s033 using Combined Features:
#  - Accuracy: 99.17%
#  - Precision: 1.00
#  - Recall: 0.95
#  - F1-Score: 0.97
#  - Training time: 0.35 seconds
#
# Metrics for user s034 using Combined Features:
#  - Accuracy: 95.83%
#  - Precision: 0.85
#  - Recall: 0.91
#  - F1-Score: 0.88
#  - Training time: 0.53 seconds
#
# Metrics for user s035 using Combined Features:
#  - Accuracy: 98.75%
#  - Precision: 0.99
#  - Recall: 0.94
#  - F1-Score: 0.96
#  - Training time: 0.43 seconds
#
# Metrics for user s036 using Combined Features:
#  - Accuracy: 99.79%
#  - Precision: 1.00
#  - Recall: 0.99
#  - F1-Score: 0.99
#  - Training time: 0.21 seconds
#
# Metrics for user s037 using Combined Features:
#  - Accuracy: 96.25%
#  - Precision: 0.88
#  - Recall: 0.90
#  - F1-Score: 0.89
#  - Training time: 0.59 seconds
#
# Metrics for user s038 using Combined Features:
#  - Accuracy: 97.50%
#  - Precision: 0.91
#  - Recall: 0.94
#  - F1-Score: 0.93
#  - Training time: 0.47 seconds
#
# Metrics for user s039 using Combined Features:
#  - Accuracy: 98.54%
#  - Precision: 0.96
#  - Recall: 0.95
#  - F1-Score: 0.96
#  - Training time: 0.44 seconds
#
# Metrics for user s040 using Combined Features:
#  - Accuracy: 98.33%
#  - Precision: 0.96
#  - Recall: 0.94
#  - F1-Score: 0.95
#  - Training time: 0.46 seconds
#
# Metrics for user s041 using Combined Features:
#  - Accuracy: 98.12%
#  - Precision: 0.93
#  - Recall: 0.96
#  - F1-Score: 0.94
#  - Training time: 0.38 seconds
#
# Metrics for user s042 using Combined Features:
#  - Accuracy: 99.58%
#  - Precision: 0.99
#  - Recall: 0.99
#  - F1-Score: 0.99
#  - Training time: 0.32 seconds
#
# Metrics for user s043 using Combined Features:
#  - Accuracy: 98.96%
#  - Precision: 0.97
#  - Recall: 0.96
#  - F1-Score: 0.97
#  - Training time: 0.28 seconds
#
# Metrics for user s044 using Combined Features:
#  - Accuracy: 98.12%
#  - Precision: 0.94
#  - Recall: 0.95
#  - F1-Score: 0.94
#  - Training time: 0.42 seconds
#
# Metrics for user s046 using Combined Features:
#  - Accuracy: 97.71%
#  - Precision: 0.92
#  - Recall: 0.95
#  - F1-Score: 0.93
#  - Training time: 0.53 seconds
#
# Metrics for user s047 using Combined Features:
#  - Accuracy: 97.92%
#  - Precision: 0.94
#  - Recall: 0.94
#  - F1-Score: 0.94
#  - Training time: 0.51 seconds
#
# Metrics for user s048 using Combined Features:
#  - Accuracy: 96.25%
#  - Precision: 0.90
#  - Recall: 0.88
#  - F1-Score: 0.89
#  - Training time: 0.48 seconds
#
# Metrics for user s049 using Combined Features:
#  - Accuracy: 99.38%
#  - Precision: 1.00
#  - Recall: 0.96
#  - F1-Score: 0.98
#  - Training time: 0.33 seconds
#
# Metrics for user s050 using Combined Features:
#  - Accuracy: 96.04%
#  - Precision: 0.89
#  - Recall: 0.88
#  - F1-Score: 0.88
#  - Training time: 0.52 seconds
#
# Metrics for user s051 using Combined Features:
#  - Accuracy: 98.12%
#  - Precision: 0.93
#  - Recall: 0.96
#  - F1-Score: 0.94
#  - Training time: 0.44 seconds
#
# Metrics for user s052 using Combined Features:
#  - Accuracy: 99.58%
#  - Precision: 1.00
#  - Recall: 0.97
#  - F1-Score: 0.99
#  - Training time: 0.25 seconds
#
# Metrics for user s053 using Combined Features:
#  - Accuracy: 98.96%
#  - Precision: 0.99
#  - Recall: 0.95
#  - F1-Score: 0.97
#  - Training time: 0.25 seconds
#
# Metrics for user s054 using Combined Features:
#  - Accuracy: 96.25%
#  - Precision: 0.87
#  - Recall: 0.91
#  - F1-Score: 0.89
#  - Training time: 0.55 seconds
#
# Metrics for user s055 using Combined Features:
#  - Accuracy: 98.75%
#  - Precision: 0.94
#  - Recall: 0.99
#  - F1-Score: 0.96
#  - Training time: 0.30 seconds
#
# Metrics for user s056 using Combined Features:
#  - Accuracy: 96.46%
#  - Precision: 0.85
#  - Recall: 0.95
#  - F1-Score: 0.90
#  - Training time: 0.43 seconds
#
# Metrics for user s057 using Combined Features:
#  - Accuracy: 97.92%
#  - Precision: 0.93
#  - Recall: 0.95
#  - F1-Score: 0.94
#  - Training time: 0.45 seconds
#
# Average Metrics Across All Users for Combined Features:
#  - Average Accuracy: 97.50%
#  - Average Precision: 0.92
#  - Average Recall: 0.94
#  - Average F1-Score: 0.93
#  - Average Training Time per User: 0.42 seconds
